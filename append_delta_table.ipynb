# %%
from delta.tables import *
DeltaTable.create(spark)\
    .tableName("employee_table")\
    .addColumn("emp_id","INT")\
    .addColumn("emp_name","STRING")\
    .addColumn("gender","STRING")\
    .addColumn("salary","INT")\
    .addColumn("Dept","STRING")\
    .property("description","table created for demo purpose")\
    .location("dbfs:/FileStore/delta/createtable")\
    .execute()
# Out:
# Out[1]: <delta.tables.DeltaTable at 0x7f9d5887acd0>

# %%
# %sql
--insert into employee_table values(100,"stephen","m",2000,"it");
--insert into employee_table values(200,"philip","m",8000,"hr");
--insert into employee_table values(300,"lara","f",6000,"sales");
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from employee_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>gender</th><th>salary</th><th>Dept</th></tr></thead><tbody><tr><td>300</td><td>lara</td><td>f</td><td>6000</td><td>sales</td></tr><tr><td>100</td><td>stephen</td><td>m</td><td>2000</td><td>it</td></tr><tr><td>100</td><td>stephen</td><td>m</td><td>2000</td><td>it</td></tr><tr><td>200</td><td>philip</td><td>m</td><td>8000</td><td>hr</td></tr></tbody></table></div>

# %%
deltainstance1=DeltaTable.forPath(spark, "/FileStore/delta/createtable")

# %%
display(deltainstance1.toDF())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>gender</th><th>salary</th><th>Dept</th></tr></thead><tbody><tr><td>300</td><td>lara</td><td>f</td><td>6000</td><td>sales</td></tr><tr><td>100</td><td>stephen</td><td>m</td><td>2000</td><td>it</td></tr><tr><td>100</td><td>stephen</td><td>m</td><td>2000</td><td>it</td></tr><tr><td>200</td><td>philip</td><td>m</td><td>8000</td><td>hr</td></tr></tbody></table></div>

# %%
deltainstance1.delete("emp_id=100")

# %%
display(deltainstance1.toDF())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>gender</th><th>salary</th><th>Dept</th></tr></thead><tbody><tr><td>300</td><td>lara</td><td>f</td><td>6000</td><td>sales</td></tr><tr><td>100</td><td>stephen</td><td>m</td><td>2000</td><td>it</td></tr><tr><td>200</td><td>philip</td><td>m</td><td>8000</td><td>hr</td></tr></tbody></table></div>

# %%
# %sql
UPDATE employee_table SET emp_id=50 where emp_name="lara"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from employee_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>gender</th><th>salary</th><th>Dept</th></tr></thead><tbody><tr><td>50</td><td>lara</td><td>f</td><td>6000</td><td>sales</td></tr><tr><td>100</td><td>stephen</td><td>m</td><td>2000</td><td>it</td></tr><tr><td>200</td><td>philip</td><td>m</td><td>8000</td><td>hr</td></tr></tbody></table></div>
